# %%
from pathlib import Path

Path(".dockerignore").touch()

print("Created:", Path(".dockerignore").resolve())
# Out:
# Created: C:\Users\nikit\BigMart_Sales_ML\.dockerignore

# %%
from pathlib import Path

file = Path(r"C:\Users\nikit\BigMart_Sales_ML\.dockerignore")

print("Exists:", file.exists())
print("Size:", file.stat().st_size, "bytes")
# Out:
# Exists: True
# Size: 180 bytes

# %%
from pathlib import Path

dockerignore = Path(r"C:\Users\nikit\BigMart_Sales_ML\.dockerignore")

dockerignore.write_text(
"""__pycache__/
*.pyc
*.pyo
*.pyd

.ipynb_checkpoints/
.pytest_cache/

.git/
.gitignore

notebooks/
reports/

*.ipynb

.env
.venv/
venv/

.streamlit/secrets.toml
""",
encoding="utf-8"
)

print("✅ .dockerignore updated successfully")
# Out:
# ✅ .dockerignore updated successfully

# %%
print(dockerignore.read_text(encoding="utf-8"))
# Out:
# __pycache__/
# *.pyc
# *.pyo
# *.pyd
#
# .ipynb_checkpoints/
# .pytest_cache/
#
# .git/
# .gitignore
#
# notebooks/
# reports/
#
# *.ipynb
#
# .env
# .venv/
# venv/
#
# .streamlit/secrets.toml

# %%
from pathlib import Path

Path(".gitignore").touch()

print("Created:", Path(".gitignore").resolve())
# Out:
# Created: C:\Users\nikit\BigMart_Sales_ML\.gitignore

# %%
from pathlib import Path

file = Path(r"C:\Users\nikit\BigMart_Sales_ML\.gitignore")

print("Exists:", file.exists())
print("Size:", file.stat().st_size, "bytes")
# Out:
# Exists: True
# Size: 131 bytes

# %%
from pathlib import Path

gitignore = Path(r"C:\Users\nikit\BigMart_Sales_ML\.gitignore")

gitignore.write_text(
"""__pycache__/
*.pyc
*.pyo
*.pyd

.ipynb_checkpoints/

.venv/
venv/

.env
.env.*

.streamlit/secrets.toml

.DS_Store
""",
encoding="utf-8"
)

print("✅ .gitignore created/updated")
# Out:
# ✅ .gitignore created/updated

# %%
print(gitignore .read_text(encoding="utf-8"))
# Out:
# __pycache__/
# *.pyc
# *.pyo
# *.pyd
#
# .ipynb_checkpoints/
#
# .venv/
# venv/
#
# .env
# .env.*
#
# .streamlit/secrets.toml
#
# .DS_Store

# %%
print(gitignore.exists())
# Out:
# True

# %%
from pathlib import Path

project = Path(r"C:\Users\nikit\BigMart_Sales_ML")

print("Project folder:", project)
print("\n.gitignore exists:", (project / ".gitignore").exists())
print(".dockerignore exists:", (project / ".dockerignore").exists())

print("\nProject files:")
for item in sorted(project.iterdir()):
    print(" -", item.name)
# Out:
# Project folder: C:\Users\nikit\BigMart_Sales_ML
#
# .gitignore exists: True
# .dockerignore exists: True
#
# Project files:
#  - .dockerignore
#  - .gitignore
#  - .ipynb_checkpoints
#  - anaconda_projects
#  - api
#  - app
#  - data
#  - data_external
#  - docker-compose.yml
#  - Dockerfile.api
#  - Dockerfile.streamlit
#  - models
#  - notebooks
#  - reports
#  - requirements.txt
#  - src
#  - Untitled.ipynb
